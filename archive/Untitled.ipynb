# %%
import os
import pandas as pd
path_1 = '/data/customers/milesquare/current/dec_thru_feb'
path_2 = '/data/customers/milesquare/refresh/201912f/customer_submission'
os.chdir(path_1)
x = pd.read_csv('dec_thru_feb_analysis.csv', sep = ',')

# %%
x
# Out:
#             Table                                       Best Version  \
# 0         billing  fhg_billing_20160901_to_20191130_folder2020011...
# 1         billing            fhg_billing_dec_2019_folder20200130.txt
# 2             bmi    fhg_bmi_20161001_to_20191231_folder20200117.txt
# 3       colectomy  fhg_colectomy_20161001_to_20191231_folder20200...
# 4         colon_2  fhg_colon_2_20100201_to_20200131_folder2020021...
# 5           demog  fhg_demog_20161001_to_20191231_folder20200117.txt
# 6    demographics  fhg_demographics_20191101_to_20200131_folder20...
# 7      enc_3_diag  fhg_enc_3_diag_20161130_to_20180131_folder2020...
# 8      hiv_screen  fhg_hiv_screen_20161001_to_20191231_folder2020...
# 9    hysterectomy  fhg_hysterectomy_20161001_to_20191231_folder20...
# 10         mammo1  fhg_mammo1_20161001_to_20191231_folder20200117...
# 11         mammo2  fhg_mammo2_20161001_to_20191231_folder20200117...
# 12     mastectomy  fhg_mastectomy_20161001_to_20191231_folder2020...
# ...

# %%
for i in x.loc[:,'Best Version']:
#     print(path_1, i, path_2)
    os.system('cp {}/{} {}'.format(path_1, i, path_2) )
